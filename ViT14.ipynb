# %%
# !pip install visualkeras
# !pip install tensorflow-addons
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.16-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.0/992.0 KB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (8.4.0)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons) (6.1.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow-addons) (3.15.0)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.19.0 typeguard-3.0.2
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
epochs = 15
pic_size = 240
np.random.seed(42)
tf.random.set_seed(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = "/content/drive/MyDrive/deep_learning/brain_tumor_dataset"
no_images = os.listdir(folder_path + '/no/')
yes_images = os.listdir(folder_path + '/yes/')
dataset=[]
lab=[]

for image_name in no_images:
    image=cv2.imread(folder_path + '/no/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(0)
    
for image_name in yes_images:
    image=cv2.imread(folder_path + '/yes/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(1)

# %%
dataset = np.array(dataset)
lab = np.array(lab)
print(dataset.shape, lab.shape)
# Out:
# (253, 240, 240, 3) (253,)

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset, lab, test_size=0.2, shuffle=True, random_state=42)

# %%
def plot_state(state):
    plt.figure(figsize= (12,12))
    for i in range(1, 10, 1):
        plt.subplot(3,3,i)
        img = load_img(folder_path + "/" + state + "/" + os.listdir(folder_path + "/" + state)[i], target_size=(pic_size, pic_size))
        plt.imshow(img)   
    plt.show()

# %%
plot_state('yes')

# %%
plot_state("no")

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 240  # We'll resize input images to this size
patch_size = 20  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
plt.figure(figsize=(8, 8))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(8, 8))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 240 X 240
# Patch size: 20 X 20
# Patches per image: 144
# Elements per patch: 1200

# %%
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=(240, 240, 3))
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(2)(features)
    # Create the Keras model.
    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 37s 37s/step - loss: 1.6539 - accuracy: 0.5000 - top-5-accuracy: 1.0000 - val_loss: 22.8134 - val_accuracy: 0.6078 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 20s 20s/step - loss: 23.6023 - accuracy: 0.6139 - top-5-accuracy: 1.0000 - val_loss: 1.5716 - val_accuracy: 0.5882 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 19s 19s/step - loss: 1.8200 - accuracy: 0.6733 - top-5-accuracy: 1.0000 - val_loss: 3.7281 - val_accuracy: 0.6078 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 19s 19s/step - loss: 4.1931 - accuracy: 0.6040 - top-5-accuracy: 1.0000 - val_loss: 3.3639 - val_accuracy: 0.3922 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 21s 21s/step - loss: 3.5804 - accuracy: 0.3960 - top-5-accuracy: 1.0000 - val_loss: 0.9278 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 1/1 [==============================] - 18s 18s/step - loss: 1.0802 - accuracy: 0.6683 - top-5-accuracy: 1.0000 - val_loss: 1.3950 - val_accuracy: 0.6275 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 1/1 [==============================] - 18s 18s/step - loss: 1.6593 - accuracy: 0.6733 - top-5-accuracy: 1.0000 - val_loss: 0.5827 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 1/1 [==============================] - 18s 18s/step - loss: 1.0182 - accuracy: 0.6782 - top-5-accuracy: 1.0000 - val_loss: 1.0287 - val_accuracy: 0.4510 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 1/1 [==============================] - 20s 20s/step - loss: 1.2564 - accuracy: 0.5891 - top-5-accuracy: 1.0000 - val_loss: 0.6189 - val_accuracy: 0.6275 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.9372 - accuracy: 0.6139 - top-5-accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 0.6275 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 1/1 [==============================] - 18s 18s/step - loss: 1.1710 - accuracy: 0.6188 - top-5-accuracy: 1.0000 - val_loss: 0.7575 - val_accuracy: 0.6275 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.9355 - accuracy: 0.7030 - top-5-accuracy: 1.0000 - val_loss: 0.5631 - val_accuracy: 0.7059 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.7881 - accuracy: 0.7129 - top-5-accuracy: 1.0000 - val_loss: 0.6803 - val_accuracy: 0.5686 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.8563 - accuracy: 0.6287 - top-5-accuracy: 1.0000 - val_loss: 0.6878 - val_accuracy: 0.5686 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 1/1 [==============================] - 24s 24s/step - loss: 1.0215 - accuracy: 0.5842 - top-5-accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.7059 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.7450 - accuracy: 0.6683 - top-5-accuracy: 1.0000 - val_loss: 0.5559 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.7435 - accuracy: 0.7129 - top-5-accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.6863 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.8067 - accuracy: 0.6634 - top-5-accuracy: 1.0000 - val_loss: 0.5651 - val_accuracy: 0.7059 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.7573 - accuracy: 0.7079 - top-5-accuracy: 1.0000 - val_loss: 0.5608 - val_accuracy: 0.7059 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.7863 - accuracy: 0.6139 - top-5-accuracy: 1.0000 - val_loss: 0.5614 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.6146 - accuracy: 0.6584 - top-5-accuracy: 1.0000 - val_loss: 0.5548 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6800 - accuracy: 0.6436 - top-5-accuracy: 1.0000 - val_loss: 0.5558 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.6078 - accuracy: 0.6931 - top-5-accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.6203 - accuracy: 0.6832 - top-5-accuracy: 1.0000 - val_loss: 0.5833 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6900 - accuracy: 0.6980 - top-5-accuracy: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6698 - accuracy: 0.7129 - top-5-accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.7074 - accuracy: 0.7030 - top-5-accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.6420 - accuracy: 0.7228 - top-5-accuracy: 1.0000 - val_loss: 0.5336 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6530 - accuracy: 0.7030 - top-5-accuracy: 1.0000 - val_loss: 0.5397 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5700 - accuracy: 0.7228 - top-5-accuracy: 1.0000 - val_loss: 0.5556 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.6723 - accuracy: 0.6931 - top-5-accuracy: 1.0000 - val_loss: 0.5983 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6464 - accuracy: 0.6832 - top-5-accuracy: 1.0000 - val_loss: 0.5975 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6232 - accuracy: 0.6980 - top-5-accuracy: 1.0000 - val_loss: 0.5559 - val_accuracy: 0.7255 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5437 - accuracy: 0.7376 - top-5-accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.6484 - accuracy: 0.7079 - top-5-accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6318 - accuracy: 0.7129 - top-5-accuracy: 1.0000 - val_loss: 0.5184 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5694 - accuracy: 0.7079 - top-5-accuracy: 1.0000 - val_loss: 0.5320 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5156 - accuracy: 0.7426 - top-5-accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6594 - accuracy: 0.6584 - top-5-accuracy: 1.0000 - val_loss: 0.5623 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5411 - accuracy: 0.7277 - top-5-accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5206 - accuracy: 0.7525 - top-5-accuracy: 1.0000 - val_loss: 0.5361 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5852 - accuracy: 0.7327 - top-5-accuracy: 1.0000 - val_loss: 0.5319 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.6370 - accuracy: 0.6881 - top-5-accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.4833 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5383 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.4855 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5502 - accuracy: 0.7228 - top-5-accuracy: 1.0000 - val_loss: 0.5471 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.5563 - accuracy: 0.7178 - top-5-accuracy: 1.0000 - val_loss: 0.5524 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 24s 24s/step - loss: 0.6950 - accuracy: 0.6634 - top-5-accuracy: 1.0000 - val_loss: 0.5502 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5459 - accuracy: 0.7426 - top-5-accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5642 - accuracy: 0.7228 - top-5-accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5249 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5103 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.5750 - accuracy: 0.7525 - top-5-accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5121 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5776 - accuracy: 0.7178 - top-5-accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5001 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.4608 - accuracy: 0.7970 - top-5-accuracy: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5265 - accuracy: 0.7178 - top-5-accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5112 - accuracy: 0.7178 - top-5-accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5717 - accuracy: 0.7327 - top-5-accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5413 - accuracy: 0.7327 - top-5-accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4760 - accuracy: 0.7624 - top-5-accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4790 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.4667 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.4871 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5162 - accuracy: 0.7426 - top-5-accuracy: 1.0000 - val_loss: 0.4906 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5537 - accuracy: 0.7624 - top-5-accuracy: 1.0000 - val_loss: 0.5035 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4828 - accuracy: 0.7723 - top-5-accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.5478 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5298 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5133 - accuracy: 0.7228 - top-5-accuracy: 1.0000 - val_loss: 0.5290 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5641 - accuracy: 0.7030 - top-5-accuracy: 1.0000 - val_loss: 0.5306 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.4866 - accuracy: 0.7277 - top-5-accuracy: 1.0000 - val_loss: 0.5252 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4784 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5256 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5057 - accuracy: 0.7673 - top-5-accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 19s 19s/step - loss: 0.5403 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.5144 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.5517 - accuracy: 0.7673 - top-5-accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.4562 - accuracy: 0.7871 - top-5-accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4925 - accuracy: 0.7277 - top-5-accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.5216 - accuracy: 0.7525 - top-5-accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4692 - accuracy: 0.7723 - top-5-accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.4613 - accuracy: 0.7673 - top-5-accuracy: 1.0000 - val_loss: 0.4967 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.4748 - accuracy: 0.7475 - top-5-accuracy: 1.0000 - val_loss: 0.4920 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4431 - accuracy: 0.7624 - top-5-accuracy: 1.0000 - val_loss: 0.4857 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4672 - accuracy: 0.7921 - top-5-accuracy: 1.0000 - val_loss: 0.4832 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4867 - accuracy: 0.7772 - top-5-accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.8235 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.4439 - accuracy: 0.7921 - top-5-accuracy: 1.0000 - val_loss: 0.4878 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4745 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4639 - accuracy: 0.7723 - top-5-accuracy: 1.0000 - val_loss: 0.5047 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.4329 - accuracy: 0.8069 - top-5-accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4813 - accuracy: 0.7426 - top-5-accuracy: 1.0000 - val_loss: 0.5293 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4570 - accuracy: 0.7822 - top-5-accuracy: 1.0000 - val_loss: 0.5344 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4573 - accuracy: 0.7772 - top-5-accuracy: 1.0000 - val_loss: 0.5379 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.4349 - accuracy: 0.8020 - top-5-accuracy: 1.0000 - val_loss: 0.5438 - val_accuracy: 0.7843 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4129 - accuracy: 0.7970 - top-5-accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4522 - accuracy: 0.8020 - top-5-accuracy: 1.0000 - val_loss: 0.5480 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4778 - accuracy: 0.7426 - top-5-accuracy: 1.0000 - val_loss: 0.5554 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 20s 20s/step - loss: 0.3955 - accuracy: 0.8317 - top-5-accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4941 - accuracy: 0.7574 - top-5-accuracy: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 17s 17s/step - loss: 0.4349 - accuracy: 0.7772 - top-5-accuracy: 1.0000 - val_loss: 0.5450 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 18s 18s/step - loss: 0.4178 - accuracy: 0.7723 - top-5-accuracy: 1.0000 - val_loss: 0.5278 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 21s 21s/step - loss: 0.3932 - accuracy: 0.7921 - top-5-accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.8039 - val_top-5-accuracy: 1.0000
# 2/2 [==============================] - 1s 436ms/step - loss: 0.5218 - accuracy: 0.8235 - top-5-accuracy: 1.0000
# Test accuracy: 82.35%
# Test top 5 accuracy: 100.0%

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# compute predictions
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 2/2 [==============================] - 3s 426ms/step

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Yes", "No"], title='Normalized confusion matrix')
plt.show()
